# %%
# %pylab inline
from density_profile import *
font = {'size':18, 'family':'serif'}
matplotlib.rc('font', **font)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
figsize(7, 5)
bb = np.linspace(0, 260, 100)
colors = ['-', '--', '-.', ':']
print len(bb)
k=0
nh_b = np.zeros(100)
for j in range(1, 11, 3):
    for i in range(100):
        nh_b[i] = nh(260.0, bb[i], j)
    plt.plot(bb, nh_b, lw=3, ls=colors[k], label='c='+str(j), c='k')
    k+=1
    yscale('log')
plt.ylabel(r'$\mathrm{N_H(cm^{-2})}$', fontsize=25)
legend(ncol=4, fontsize=14, loc='lower center')
plt.xlabel(r'$\mathrm{Impact\ parameter\ b(kpc)}$', fontsize=25)
savefig('../figures/NH-b.eps', bbox_inches='tight')
# Out:
# 100

# %% [markdown]
# check Fig5. in: http://adsabs.harvard.edu/abs/2011ApJ...740..102K

# %%
def concentration(M):
    cc = 9.6 * (M/1E12)**(-0.075)
    return cc

# %%
concentration(2e12)
# Out:
# 9.113684361124983

# %%
rhog0 = np.zeros(10)
for i in range(1,11):
    rhog0[i-1] = rho_g0(6.0, i).value

# %%
plot(log10(rhog0))
